# %%
class Student:
    def __init__(self,name,rollNumber):
#     def __init__(self):
        
        self.name = name
        self.rollNumber = rollNumber

# %%
s1 = Student()
s1.name = 'ankush'
s1.rollNumber = 12

# %%
s1.__dict__
# Out:
# {'name': 'ankush', 'rollNumber': 12}

# %%
s2 = Student()
s2.name = 'rohan'
s2.rollNumber = 13

# %%
s2.__dict__
# Out:
# {'name': 'rohan', 'rollNumber': 13}

# %%
s1, s2
# Out:
# (<__main__.Student at 0x23bcfb2fe20>, <__main__.Student at 0x23bcf19f610>)

# %%
s3 = Student('priya',14)

# %%
s3.__dict__
# Out:
# {'name': 'priya', 'rollNumber': 14}

# %% [markdown]
# # instance methods
