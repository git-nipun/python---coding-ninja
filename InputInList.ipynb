# %%
n = int(input())

li = []
for i in range(n):
    curr = int(input())
    li.append(curr)
# Out:
# 5
# 2
# 3
# 4
# 5
# 6

# %%
li
# Out:
# [2, 3, 4, 5, 6]

# %%
for ele in li:
    print(ele)
# Out:
# 2
# 3
# 4
# 5
# 6
