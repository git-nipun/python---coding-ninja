# %%
def replace(str,char1,char2):
    newStr = ""
    for char in str:
        if(char == char1):
            newStr = newStr + char2
        else:
            newStr = newStr + char
    return newStr

str = "fsafsavxz"
str = replace(str,'s','d')
print(str)
# Out:
# fdafdavxz
