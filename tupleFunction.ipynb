# %%
a = (1,2,3)
b = 4,5

# %%
for i in a:
    print(i)
# Out:
# 1
# 2
# 3

# %%
1 in a
# Out:
# True

# %%
1 in b
# Out:
# False

# %%
len(a)
# Out:
# 3

# %%
c = a + b
print(c)
# Out:
# (1, 2, 3, 4, 5)

# %%
d = (a,b)
print(d)
# Out:
# ((1, 2, 3), (4, 5))

# %%
e = a * 4
e
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
max(a)
# Out:
# 3

# %%
a2 = (1,2,"s",(1,2))
min(a2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-43847f5517c6> in <module>
#       1 a2 = (1,2,"s",(1,2))
# ----> 2 min(a2)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
a2 = (1,2,(1,2))
min(a2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-542f4d847e5e> in <module>
#       1 a2 = (1,2,(1,2))
# ----> 2 min(a2)
#
# TypeError: '<' not supported between instances of 'tuple' and 'int'

# %%
a2 = (1,2,(1,2))
a3 = (1,2.2)
min(a3)
# Out:
# 1

# %%
# list to tuple

l = [1,2,3,4]
tuple(l)
type(l)
# Out:
# list
