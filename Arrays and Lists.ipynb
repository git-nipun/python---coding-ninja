# %% [markdown]
# # creating a list

# %%
li = []

# %%
li = [1,2,3]

# %%
type(li)
# Out:
# list

# %%
li = [1,2,]

# %%
li = [1,2,"parikh", 3.4]

# %%
li

# %%
[1,2,'parikh', 3.4]
# Out:
# [1, 2, 'parikh', 3.4]

# %% [markdown]
# # access and change elements in the LIST

# %%
li[0]
# Out:
# 1

# %%
li[2]
# Out:
# 3

# %%
li[3] = "rohan"

# %%
li
# Out:
# [1, 2, 'parikh', 'rohan']

# %% [markdown]
# slicing of a LIST

# %%
li[1:3]
# Out:
# [2, 'parikh']

# %%
li[1:]
# Out:
# [2, 'parikh', 'rohan']

# %% [markdown]
# insert and append elements in the list

# %%
li.append("ankush")

# %%
li
# Out:
# [1, 2, 'parikh', 'rohan', 'ankush']

# %%
li.insert(1,7)

# %%
li
# Out:
# [1, 7, 2, 'parikh', 'rohan', 'ankush']

# %%
li.insert(6,10)

# %%
li
# Out:
# [1, 7, 2, 'parikh', 'rohan', 'ankush', 10]

# %%
li.insert(9,"karen")

# %%
li
# Out:
# [1, 7, 2, 'parikh', 'rohan', 'ankush', 10, 'karen']

# %%
li.append((9,10,11))

# %%
li
# Out:
# [1, 7, 2, 'parikh', 'rohan', 'ankush', 10, 'karen', (9, 10, 11)]

# %%
li.extend((9,10,11))

# %%
li
# Out:
# [1, 7, 2, 'parikh', 'rohan', 'ankush', 10, 'karen', (9, 10, 11), 9, 10, 11]

# %% [markdown]
# removing elements from the LIST

# %%
li.remove(2)

# %%
li
# Out:
# [1, 7, 'parikh', 'rohan', 'ankush', 10, 'karen', (9, 10, 11), 9, 10, 11]

# %%
li.append(5)

# %%
li
# Out:
# [1, 7, 'parikh', 'rohan', 'ankush', 10, 'karen', (9, 10, 11), 9, 10, 11, 5]

# %%
li.remove(5)

# %%
li
# Out:
# [1, 7, 'parikh', 'rohan', 'ankush', 10, 'karen', (9, 10, 11), 9, 10, 11]

# %%
li.pop()
# Out:
# 11

# %%
li
# Out:
# [1, 7, 'parikh', 'rohan', 'ankush', 10, 'karen', (9, 10, 11), 9, 10]

# %%
li.pop(2)
# Out:
# 'parikh'

# %%
li
# Out:
# [1, 7, 'rohan', 'ankush', 10, 'karen', (9, 10, 11), 9, 10]
