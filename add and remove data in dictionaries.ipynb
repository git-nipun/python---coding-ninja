# %%
a = {1:2, 3:4, "list":[1,23], "dict":{1:2}}

# %%
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 2}}

# %%
a['t'] = {1,2,3}

# %%
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 2}, 't': {1, 2, 3}}

# %%
a[1] = 10

# %%
a
# Out:
# {1: 10, 3: 4, 'list': [1, 23], 'dict': {1: 2}, 't': {1, 2, 3}}

# %%
b = {3:5, 'the':2, 2:100}

# %%
a.update(b)

# %%
a
# Out:
# {1: 10,
#  3: 5,
#  'list': [1, 23],
#  'dict': {1: 2},
#  't': {1, 2, 3},
#  'the': 2,
#  2: 100}

# %%
a.pop('t')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-a17f7037e8bb> in <module>
# ----> 1 a.pop('t')
#
# KeyError: 't'

# %%
a
# Out:
# {1: 10, 3: 5, 'list': [1, 23], 'dict': {1: 2}, 'the': 2, 2: 100}

# %%
del a[1]

# %%
a
# Out:
# {3: 5, 'list': [1, 23], 'dict': {1: 2}, 'the': 2, 2: 100}

# %%
a.clear()

# %%
a
# Out:
# {}

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined
