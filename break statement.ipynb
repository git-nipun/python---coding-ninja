# %% [markdown]
# ### BREAK

# %%
n = int(input())
d =2
flag = False
while d < n:
    if(n%d==0):
        flag = True
    d=d+1
    
    if flag:
        print("not prime")
    else:
        print("prime")

# %%
n = int(input())
flag = Flase
for d in range(2,n,1):
    if n%d==0:
        flag = True
if flag:
    print("not prime")
else:
    print("prime")
# Out:
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6c873f75c60f> in <module>
#       1 n = int(input())
# ----> 2 flag = Flase
#       3 for d in range(2,n,1):
#       4     if n%d==0:
#       5         flag = True
#
# NameError: name 'Flase' is not defined

# %%
i = 1
while i < 10:
    if i == 5:
        break
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4

# %%
n = int(input())
d =2
flag = False
while d < n:
    if(n%d==0):
        flag = True
        break
    d=d+1
    
if flag:
    print("not prime")
else:
    print("prime")
# Out:
# 12345678
# not prime

# %%
n = int(input())
flag = False
for d in range(2,n,1):
    if n%d==0:
        flag = True
        break
if flag:
    print("not prime")
else:
    print("prime")
# Out:
# 10
# not prime

# %%
n = int(input())
k = 2
while k <= n:
    d = 2
    flag = False
    while d < k:
        if k % d == 0:
            flag = True
            break
        d = d + 1
    if(not(flag)):
        print(k)
    k = k + 1
# Out:
# 25
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19
# 23
