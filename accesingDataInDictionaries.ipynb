# %%
a = {1:2, 3:4, "list":[1,23], "dict":{1:2}}

# %%
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 2}}

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-6a1284577a36> in <module>
# ----> 1 a[0]
#
# KeyError: 0

# %%
a['list']
# Out:
# [1, 23]

# %%
a.get('list')
# Out:
# [1, 23]

# %%
print(a.get('li'))
# Out:
# None

# %%
a.get('li',0)
# Out:
# 0

# %%
a.keys()
# Out:
# dict_keys([1, 3, 'list', 'dict'])

# %%
a.values()
# Out:
# dict_values([2, 4, [1, 23], {1: 2}])

# %%
a.items()
# Out:
# dict_items([(1, 2), (3, 4), ('list', [1, 23]), ('dict', {1: 2})])

# %%
for i in a:
    print(i,a[i])
# Out:
# 1 2
# 3 4
# list [1, 23]
# dict {1: 2}

# %%
for i in a.values():
    print(i)
# Out:
# 2
# 4
# [1, 23]
# {1: 2}

# %%
"list" in a
# Out:
# True

# %%
'li' in a
# Out:
# False

# %%
2 in a
# Out:
# False
