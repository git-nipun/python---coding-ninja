# %% [markdown]
# # classes and objects

# %%
class Student:
    pass

# %%
s1 = Student()

# %%
print(type(s1))
l = list()
print(type(l))
# Out:
# <class '__main__.Student'>
# <class 'list'>

# %%
s2 = Student()
s3 = Student()
print(s2,s3)
# Out:
# <__main__.Student object at 0x000001C523FC8160> <__main__.Student object at 0x000001C523FC8400>

# %% [markdown]
# # instance attributes

# %%
s1.name = "ankush"
s1.rollNumber = 12

# %%
s3.name = "Rohan"
s3.rollNumber = 13

# %%
s1.name
# Out:
# 'ankush'

# %%
s3.name
# Out:
# 'Rohan'

# %%
s2.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-709594944e69> in <module>
# ----> 1 s2.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
s1.__dict__
# Out:
# {'name': 'ankush', 'rollNumber': 12}

# %%
s2.__dict__
# Out:
# {}

# %%
s3.__dict__
# Out:
# {'name': 'Rohan', 'rollNumber': 13}

# %%
hasattr(s1,'name')
# Out:
# True

# %%
hasattr(s2,'name')
# Out:
# False

# %%
getattr(s1,'name')
# Out:
# 'ankush'

# %%
getattr(s2,'name')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ff670ab04ded> in <module>
# ----> 1 getattr(s2,'name')
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
getattr(s2,'name','')
# Out:
# ''

# %%
getattr(s1,'name','')
# Out:
# 'ankush'

# %%
delattr(s1,'name')

# %%
s1.__dict__
# Out:
# {'rollNumber': 12}
