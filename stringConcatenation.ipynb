# %%
a = "red"

# %%
a
# Out:
# 'red'

# %%
a = a + "blue" + "green"

# %%
a
# Out:
# 'redbluebluegreen'

# %%
a = "blue"

# %%
a = a*3

# %%
a
# Out:
# 'blueblueblue'

# %%
a=a*3

# %%
a
# Out:
# 'blueblueblueblueblueblueblueblueblue'

# %%
a = "red"

# %%
a = a + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-b43c28ac8d2f> in <module>
# ----> 1 a = a + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = a + str(3)

# %%
a
# Out:
# 'red3'
