# %% [raw]
# ****
# ***
# **
# *

# %%
n = int(input())
i = 1
while(i<=n):
    j = 1
    while(j<=(n-i+1)):
        
        print("*", end='')
        j=j+1
    print()
    i = i + 1
# Out:
# 4
# ****
# ***
# **
# *

# %% [raw]
# 1234
# 123
# 12
# 1

# %%
n = int(input())
i = 1
while(i<=n):
    j = 1
    p = 1
    while(j<=n-i+1):

        print(p,end='')
        p =p + 1 
        j = j + 1
    print()
    i = i + 1
# Out:
# 4
# 1234
# 123
# 12
# 1

# %% [raw]
# ---*
# --**
# -***
# ****

# %%
n = int(input())
i =1 
while(i<=n):
#     spaces
    space = 1
    while(space<=n-i):
        print("-",end='')
        space = space+1
#     stars
    j = 1
    while(j<=i):
        print("*", end='')
        j = j + 1
    print()
    i = i + 1
# Out:
# 4
# ---*
# --**
# -***
# ****

# %% [raw]
# ---1
# --121
# -12321
# 1234321

# %%
# OWN CODE

n = int(input())
i = 1 
while(i <= n):
 #     spaces
    
    spaces = 1
    while(spaces <= n-i):
        print("-", end='')
        spaces = spaces + 1
        
#     number
    num = 1
    while(num <= i):
        print(num,end="")
        num = num + 1
        
#     remaining number
    rem_num = i-1
    while(rem_num!=0):
        print(rem_num, end="")
        rem_num = rem_num - 1
    
    print()
    i = i + 1
# Out:
# 4
# ---1
# --121
# -12321
# 1234321

# %% [raw]
# ---1
# --12
# -123
# 1234

# %%
n = int(input())

i = 1
while(i <=n):
    spaces = 1
    while(spaces<=n-i):
        print(" ", end="")
        spaces = spaces + 1
    
    inc_num = 1
    j = 1
    while(j<=i):
        print(inc_num,end="")
        inc_num = inc_num + 1
        j = j + 1
        
    dec_num = i - 1
    while(dec_num>0):
        
        print(dec_num,end='')
        dec_num = dec_num - 1
    
    print()
    i = i + 1
# Out:
# 4
#    1
#   121
#  12321
# 1234321
