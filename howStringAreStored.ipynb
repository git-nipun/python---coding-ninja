# %%
s = "parikh"

# %%
id(s)
# Out:
# 2176583880368

# %%
print(s)
# Out:
# parikh

# %%
a = "rohan"

# %%
print(a)
# Out:
# rohan

# %%
id(a)
# Out:
# 2176584197424

# %%
a = "parikh"

# %%
id(a)
# Out:
# 2176583880368

# %%
id(s)
# Out:
# 2176583880368

# %% [markdown]
# string are Immutable in python

# %%
a = "parikh"

# %%
print(a[0])
# Out:
# p

# %%
a[0] = "r"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d960047bcbb3> in <module>
# ----> 1 a[0] = "r"
#
# TypeError: 'str' object does not support item assignment
