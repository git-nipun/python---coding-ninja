# %% [markdown]
# Immutable

# %%
x = 3
a = 3
print(x)
# Out:
# 3

# %%
id(x)
# Out:
# 2331882908016

# %%
id(a)
# Out:
# 2331882908016

# %%
a = 4

# %%
id(a)
# Out:
# 2331882908048

# %%
x
# Out:
# 3

# %%
a
# Out:
# 4

# %%
li = [1,2,3,4]
li2 = li
li2 = [3,3,4]
li2[1] = 4

# %%
print(li)
print(li2)
# Out:
# [1, 2, 3, 4]
# [3, 4, 4]
