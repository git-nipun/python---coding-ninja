# %%
a = {1,2,3,4}
b = {3,4,5,6}

# %%
a.intersection(b)
# Out:
# {3, 4}

# %%
a.union(b)
# Out:
# {3, 4, 5, 6}

# %%
a.difference(b)
# Out:
# {1, 2}

# %%
b.difference(a)
# Out:
# {5, 6}

# %%
a.symmetric_difference(b)
# Out:
# {1, 2, 5, 6}

# %%
b.symmetric_difference(a)
# Out:
# {1, 2, 5, 6}

# %%
a.intersection_update(b)

# %%
a
# Out:
# {3, 4}

# %%
a.difference_update(b)

# %%
a
# Out:
# {1, 2}

# %%
a.symmetric_difference_update(b)

# %%
a
# Out:
# {1, 2, 5, 6}

# %%
a.union_update(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-3020a840e4b2> in <module>
# ----> 1 a.union_update(b)
#
# AttributeError: 'set' object has no attribute 'union_update'

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
b
# Out:
# {3, 4, 5, 6}

# %%
a.issubset(b)
# Out:
# False

# %%
c = {3,4}

# %%
a.issubset(c)
# Out:
# False

# %%
c.issubset(a)
# Out:
# True
