# %%
li = [ [1,2,3,4] , [5,6,7,8,] , [11,12,13,14] ]

# %%
n = 3
m = 4

# %%
 for i in range(n):
        for j in range(m):
            print(li[i][j], end=' ')
        print()
# Out:
# 1 2 3 4
# 5 6 7 8
# 11 12 13 14

# %%
li = [ [1,2,3,4] , [5,6] , [9,10,11] ]
n = 3
for row in li:
    for ele in row:
        print(ele,end=' ')
    print()
# Out:
# 1 2 3 4
# 5 6
# 9 10 11

# %%
'ab'.join('abcd')
# Out:
# 'aabbabcabd'

# %%
'ab'.join(['1','2','3'])
# Out:
# '1ab2ab3'

# %%
li = [ [1,2,3,4] , [5,6] , [9,10,11] ]
n = 3
for row in li:
    output = ' '.join([str(ele) for ele in row])
    print(output)
# Out:
# 1 2 3 4
# 5 6
# 9 10 11
